# %%
a = [1, 2]
print(a)

a = [3,4]
print(a)

print(a[0])
print(a[1])
# Out:
# [1, 2]
# [3, 4]
# 3
# 4

# %%
from collections import deque

def solution(numbers, hand):
    answer = ''
    L_now = [3, 0]
    R_now = [3, 2]
    
    numbers = deque(numbers)
    
    while numbers:
        now = numbers.popleft()
        
        if now == 1:
            L_now = [0, 0]
            answer += 'L'
        elif now == 4:
            L_now = [1, 0]
            answer += 'L'
        elif now == 7:
            L_now = [2, 0]
            answer += 'L'
            
        elif now == 3:
            R_now = [0, 2]
            answer += 'R'
        elif now == 6:
            R_now = [1, 2]
            answer += 'R'
        elif now == 9:
            R_now = [2, 2]
            answer += 'R'
            
        elif now == 2:
            R_dis = abs(R_now[0] - 0) + abs(R_now[1] - 1)
            L_dis = abs(L_now[0] - 0) + abs(L_now[1] - 1)
            if R_dis < L_dis:
                R_now = [0, 1]
                answer += 'R'
            elif R_dis > L_dis:
                L_now = [0, 1]
                answer += 'L'
            else:
                if hand == "right":
                    R_now = [0, 1]
                    answer += 'R'
                else:
                    L_now = [0, 1]
                    answer += 'L'
                    
        elif now == 5:
            R_dis = abs(R_now[0] - 1) + abs(R_now[1] - 1)
            L_dis = abs(L_now[0] - 1) + abs(L_now[1] - 1)
            if R_dis < L_dis:
                R_now = [1, 1]
                answer += 'R'
            elif R_dis > L_dis:
                L_now = [1, 1]
                answer += 'L'
            else:
                if hand == "right":
                    R_now = [1, 1]
                    answer += 'R'
                else:
                    L_now = [1, 1]
                    answer += 'L'
                    
        elif now == 8:
            R_dis = abs(R_now[0] - 2) + abs(R_now[1] - 1)
            L_dis = abs(L_now[0] - 2) + abs(L_now[1] - 1)
            if R_dis < L_dis:
                R_now = [2, 1]
                answer += 'R'
            elif R_dis > L_dis:
                L_now = [2, 1]
                answer += 'L'
            else:
                if hand == "right":
                    R_now = [2, 1]
                    answer += 'R'
                else:
                    L_now = [2, 1]
                    answer += 'L'
                    
        elif now == 0:
            R_dis = abs(R_now[0] - 3) + abs(R_now[1] - 1)
            L_dis = abs(L_now[0] - 3) + abs(L_now[1] - 1)
            if R_dis < L_dis:
                R_now = [3, 1]
                answer += 'R'
            elif R_dis > L_dis:
                L_now = [3, 1]
                answer += 'L'
            else:
                if hand == "right":
                    R_now = [3, 1]
                    answer += 'R'
                else:
                    L_now = [3, 1]
                    answer += 'L'
            
                    
        
        
    return answer
